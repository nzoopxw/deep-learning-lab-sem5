# %%
# !pip install -q "scikeras>=0.13.0"
import tensorflow as tf, keras, scikeras, os
print("TF:", tf.__version__, "| Keras:", keras.__version__, "| SciKeras:", scikeras.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
os.makedirs("plots", exist_ok=True)
# Out:
# TF: 2.20.0 | Keras: 3.13.2 | SciKeras: 0.13.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !apt-get install -qq -y msttcorefonts > /dev/null 2>&1
# !rm -rf ~/.cache/matplotlib
import os; os.makedirs("/root/.cache/matplotlib", exist_ok=True)
import matplotlib.font_manager as fm
fm._load_fontmanager(try_read_cache=False)

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, time
import tensorflow as tf
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input
from keras.utils import to_categorical
from keras.optimizers import Adam, SGD, RMSprop
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, confusion_matrix, classification_report)

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({
    'font.family': 'serif',
    'font.serif': ['Times New Roman', 'Liberation Serif', 'DejaVu Serif'],
    'font.size': 12,
    'axes.titlesize': 12,
    'axes.labelsize': 12,
    'axes.titleweight': 'bold',
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'legend.fontsize': 11,
    'figure.facecolor': 'white',
    'savefig.facecolor': 'white',
})

np.random.seed(42); tf.random.set_seed(42)

CLASS_NAMES = ['T-shirt/top','Trouser','Pullover','Dress','Coat',
               'Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
# task 1

# loading Fashion-MNIST dataset
(x_train_raw, y_train_raw), (x_test_raw, y_test_raw) = fashion_mnist.load_data()

# printing dataset dimensions
print("Training images :", x_train_raw.shape)
print("Training labels :", y_train_raw.shape)
print("Testing images  :", x_test_raw.shape)
print("Testing labels  :", y_test_raw.shape)
print("Pixel range     :", x_train_raw.min(), "to", x_train_raw.max())
print("Number of classes:", len(np.unique(y_train_raw)))
# Out:
# Training images : (60000, 28, 28)
# Training labels : (60000,)
# Testing images  : (10000, 28, 28)
# Testing labels  : (10000,)
# Pixel range     : 0 to 255
# Number of classes: 10

# %%
# task 1

# displaying 10 sample images
fig, axes = plt.subplots(2, 5, figsize=(10, 4))
for i, ax in enumerate(axes.flat):
    ax.imshow(x_train_raw[i], cmap='gray')
    ax.set_title(CLASS_NAMES[y_train_raw[i]], fontsize=10)
    ax.axis('off')
plt.suptitle("Fashion-MNIST — Ten Sample Training Images")
plt.tight_layout()
plt.savefig("plots/01_sample_images.png", dpi=150, bbox_inches='tight')
plt.show()

# %%
# task 1

counts = np.bincount(y_train_raw)
plt.figure(figsize=(10, 4))
colours = [
    "#FF6B6B",
    "#F7B267",
    "#FFD166",
    "#06D6A0",
    "#118AB2",
    "#073B4C",
    "#9B5DE5",
    "#F15BB5",
    "#00BBF9",
    "#00F5D4"
]

plt.bar(CLASS_NAMES, counts,
        color=colours,
        edgecolor="black")
plt.ylabel("Number of training images")
plt.xticks(rotation=45, ha='right')
plt.title("Fashion-MNIST Training Set: Class Distribution")
for i, c in enumerate(counts):
    plt.text(i, c + 60, str(c), ha='center', fontsize=8)
plt.tight_layout()
plt.savefig("plots/02_class_distribution.png", dpi=150, bbox_inches='tight')
plt.show()
print("Counts per class:", counts)
# Out:
# Counts per class: [6000 6000 6000 6000 6000 6000 6000 6000 6000 6000]

# %%
# task 2

print("Before preprocessing: ")
print("  x_train:", x_train_raw.shape, "| dtype:", x_train_raw.dtype)
print("  x_test :", x_test_raw.shape,  "| dtype:", x_test_raw.dtype)
print("  y_train:", y_train_raw.shape, "| dtype:", y_train_raw.dtype)
print("  Pixel range:", x_train_raw.min(), "to", x_train_raw.max())

# Flattening 28x28 -> 784
x_train_full = x_train_raw.reshape(-1, 784).astype('float32')/255.0
x_test       = x_test_raw.reshape(-1, 784).astype('float32')/255.0

# One-hot encoding labels [integer to vectors of length 10]
y_train_full = to_categorical(y_train_raw, 10)
y_test       = to_categorical(y_test_raw, 10)

print("\nAfter preprocessing: ")
print("  x_train:", x_train_full.shape, "| dtype:", x_train_full.dtype)
print("  x_test :", x_test.shape,       "| dtype:", x_test.dtype)
print("  y_train:", y_train_full.shape, "(one-hot)")
print("  Pixel range:", x_train_full.min(), "to", x_train_full.max())
# Out:
# Before preprocessing:
#   x_train: (60000, 28, 28) | dtype: uint8
#   x_test : (10000, 28, 28) | dtype: uint8
#   y_train: (60000,) | dtype: uint8
#   Pixel range: 0 to 255
#
# After preprocessing:
#   x_train: (60000, 784) | dtype: float32
#   x_test : (10000, 784) | dtype: float32
#   y_train: (60000, 10) (one-hot)
#   Pixel range: 0.0 to 1.0

# %%
# task 3

baseline = Sequential([
    Input(shape=(784,)),
    Dense(128, activation='relu'),
    Dense(64,  activation='relu'),
    Dense(10,  activation='softmax')
])

baseline.compile(optimizer='adam',
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])

baseline.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# task 4

# Validation split for the training-curve plots
x_tr, x_val, y_tr, y_val = train_test_split(
    x_train_full, y_train_full, test_size=10000, random_state=42)
print("Train split:", x_tr.shape, "| Validation split:", x_val.shape, "\n")

# Adam, Categorical Cross Entropy, Accuracy
baseline.compile(optimizer='adam',
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])

# Training for 20 epochs, batch size 32
t0 = time.perf_counter()
history = baseline.fit(x_tr, y_tr,
                       validation_data=(x_val, y_val),
                       epochs=20, batch_size=32, verbose=2)
baseline_time = time.perf_counter() - t0
print(f"\nBaseline training time: {baseline_time:.1f} s")
# Out:
# Train split: (50000, 784) | Validation split: (10000, 784)
#
# Epoch 1/20
# 1563/1563 - 16s - 10ms/step - accuracy: 0.8196 - loss: 0.5046 - val_accuracy: 0.8501 - val_loss: 0.4052
# Epoch 2/20
# 1563/1563 - 10s - 7ms/step - accuracy: 0.8614 - loss: 0.3746 - val_accuracy: 0.8650 - val_loss: 0.3692
# Epoch 3/20
# 1563/1563 - 5s - 3ms/step - accuracy: 0.8767 - loss: 0.3350 - val_accuracy: 0.8683 - val_loss: 0.3558
# Epoch 4/20
# 1563/1563 - 4s - 3ms/step - accuracy: 0.8841 - loss: 0.3094 - val_accuracy: 0.8734 - val_loss: 0.3450
# Epoch 5/20
# 1563/1563 - 4s - 3ms/step - accuracy: 0.8908 - loss: 0.2912 - val_accuracy: 0.8773 - val_loss: 0.3304
# Epoch 6/20
# 1563/1563 - 5s - 3ms/step - accuracy: 0.8963 - loss: 0.2741 - val_accuracy: 0.8781 - val_loss: 0.3291
# Epoch 7/20
# 1563/1563 - 4s - 3ms/step - accuracy: 0.9015 - loss: 0.2615 - val_accuracy: 0.8804 - val_loss: 0.3316
# Epoch 8/20
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9059 - loss: 0.2508 - val_accuracy: 0.8775 - val_loss: 0.3374
# Epoch 9/20
# 1563/1563 - 4s - 3ms/step - accuracy: 0.9109 - loss: 0.2391 - val_accuracy: 0.8806 - val_loss: 0.3376
# Epoch 10/20
# 1563/1563 - 4s - 3ms/step - accuracy: 0.9132 - loss: 0.2304 - val_accuracy: 0.8828 - val_loss: 0.3419
# Epoch 11/20
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9169 - loss: 0.2200 - val_accuracy: 0.8784 - val_loss: 0.3553
# Epoch 12/20
# 1563/1563 - 4s - 3ms/step - accuracy: 0.9201 - loss: 0.2141 - val_accuracy: 0.8830 - val_loss: 0.3516
# Epoch 13/20
# 1563/1563 - 4s - 3ms/step - accuracy: 0.9228 - loss: 0.2061 - val_accuracy: 0.8817 - val_loss: 0.3579
# Epoch 14/20
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9247 - loss: 0.1984 - val_accuracy: 0.8799 - val_loss: 0.3713
# Epoch 15/20
# 1563/1563 - 4s - 3ms/step - accuracy: 0.9288 - loss: 0.1924 - val_accuracy: 0.8779 - val_loss: 0.3845
# Epoch 16/20
# 1563/1563 - 4s - 3ms/step - accuracy: 0.9303 - loss: 0.1870 - val_accuracy: 0.8753 - val_loss: 0.3959
# Epoch 17/20
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9319 - loss: 0.1817 - val_accuracy: 0.8777 - val_loss: 0.3936
# Epoch 18/20
# 1563/1563 - 4s - 3ms/step - accuracy: 0.9341 - loss: 0.1768 - val_accuracy: 0.8791 - val_loss: 0.4020
# Epoch 19/20
# 1563/1563 - 7s - 5ms/step - accuracy: 0.9352 - loss: 0.1716 - val_accuracy: 0.8772 - val_loss: 0.3969
# Epoch 20/20
# 1563/1563 - 7s - 5ms/step - accuracy: 0.9369 - loss: 0.1695 - val_accuracy: 0.8766 - val_loss: 0.4080
#
# Baseline training time: 115.6 s

# %%
# task 5

def evaluate(model, name):
    probs = model.predict(x_test, verbose=0)
    pred  = np.argmax(probs, axis=1)          # one-hot probs -> integer labels
    metrics = dict(
        accuracy  = accuracy_score(y_test_raw, pred),
        precision = precision_score(y_test_raw, pred, average='macro'),
        recall    = recall_score(y_test_raw, pred, average='macro'),
        f1        = f1_score(y_test_raw, pred, average='macro'))
    print(f"===== {name} =====")
    for k, v in metrics.items():
        print(f"  {k.capitalize():10s}: {v:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test_raw, pred,
                                target_names=CLASS_NAMES, digits=4))
    return metrics, pred

baseline_metrics, baseline_pred = evaluate(baseline, "BASELINE MODEL")
# Out:
# ===== BASELINE MODEL =====
#   Accuracy  : 0.8695
#   Precision : 0.8742
#   Recall    : 0.8695
#   F1        : 0.8704
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  T-shirt/top     0.8659    0.7490    0.8032      1000
#      Trouser     0.9888    0.9710    0.9798      1000
#     Pullover     0.7951    0.7450    0.7692      1000
#        Dress     0.9146    0.8250    0.8675      1000
#         Coat     0.7586    0.8170    0.7867      1000
#       Sandal     0.9446    0.9720    0.9581      1000
#        Shirt     0.6429    0.7560    0.6949      1000
#      Sneaker     0.9354    0.9410    0.9382      1000
#          Bag     0.9271    0.9790    0.9523      1000
#   Ankle boot     0.9691    0.9400    0.9543      1000
#
#     accuracy                         0.8695     10000
#    macro avg     0.8742    0.8695    0.8704     10000
# weighted avg     0.8742    0.8695    0.8704     10000

# %%
  # task 5 - confusion matrix

def plot_cm(pred, title, fname):
    cm = confusion_matrix(y_test_raw, pred)
    fig, ax = plt.subplots(figsize=(8, 7))
    im = ax.imshow(cm, cmap='YlOrRd')
    fig.colorbar(im)
    ax.set_xticks(range(10)); ax.set_yticks(range(10))
    ax.set_xticklabels(CLASS_NAMES, rotation=45, ha='right')
    ax.set_yticklabels(CLASS_NAMES)
    ax.set_xlabel("Predicted"); ax.set_ylabel("True"); ax.set_title(title)
    for i in range(10):
        for j in range(10):
            ax.text(j, i, cm[i, j], ha='center', va='center', fontsize=7,
                    color='white' if cm[i, j] > cm.max()/2 else 'black')
    plt.tight_layout()
    plt.savefig(f"plots/{fname}.png", dpi=150, bbox_inches='tight')
    plt.show()
    return cm

cm_base = plot_cm(baseline_pred, "Confusion Matrix — Baseline MLP", "07_confusion_baseline")

# %%
# 7

def build_model(n_layers=2, n_neurons=128, activation='relu',
                dropout=0.0, optimizer='adam', learning_rate=0.001):
    model = Sequential([Input(shape=(784,))])
    for _ in range(n_layers):
        model.add(Dense(n_neurons, activation=activation))
        if dropout > 0:
            model.add(Dropout(dropout))
    model.add(Dense(10, activation='softmax'))
    opt = {'adam': Adam, 'sgd': SGD, 'rmsprop': RMSprop}[optimizer](learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

clf = KerasClassifier(model=build_model, verbose=0,
                      n_layers=2, n_neurons=128, activation='relu',
                      dropout=0.0, optimizer='adam', learning_rate=0.001,
                      loss='categorical_crossentropy')

# %%
# !pip install -q --upgrade "scikeras>=0.13.0" "scikit-learn>=1.6"

# %%
import sklearn, scikeras
print("sklearn:", sklearn.__version__, "| scikeras:", scikeras.__version__)
# Out:
# sklearn: 1.9.0 | scikeras: 0.13.0

# %%
param_dist = {
    'n_layers':      [1, 2, 3],
    'n_neurons':     [32, 64, 128, 256],
    'learning_rate': [0.1, 0.01, 0.001],
    'batch_size':    [16, 32, 64, 128],
    'epochs':        [10],
    'optimizer':     ['sgd', 'adam', 'rmsprop'],
    'activation':    ['relu', 'tanh', 'sigmoid'],
    'dropout':       [0.0, 0.2, 0.5],
}

# Subsample training data
SUB = 15000
idx = np.random.choice(len(x_train_full), SUB, replace=False)
x_sub, y_sub = x_train_full[idx], y_train_full[idx]

search = RandomizedSearchCV(clf, param_dist, n_iter=20, cv=5, n_jobs=1,
                            verbose=2, random_state=42, scoring='accuracy')
t0 = time.perf_counter()
search.fit(x_sub, y_sub)
search_time = (time.perf_counter() - t0) / 60
print(f"\nSearch wall time: {search_time:.1f} min")

pd.DataFrame(search.cv_results_).to_csv("cv_results.csv", index=False)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END activation=sigmoid, batch_size=32, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=1, n_neurons=128, optimizer=sgd; total time=  24.4s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=1, n_neurons=128, optimizer=sgd; total time=  12.0s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=1, n_neurons=128, optimizer=sgd; total time=  13.0s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=1, n_neurons=128, optimizer=sgd; total time=  12.1s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=1, n_neurons=128, optimizer=sgd; total time=  12.3s
# [CV] END activation=sigmoid, batch_size=64, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=64, optimizer=sgd; total time=  10.6s
# [CV] END activation=sigmoid, batch_size=64, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=64, optimizer=sgd; total time=   9.1s
# [CV] END activation=sigmoid, batch_size=64, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=64, optimizer=sgd; total time=  10.0s
# [CV] END activation=sigmoid, batch_size=64, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=64, optimizer=sgd; total time=  12.1s
# [CV] END activation=sigmoid, batch_size=64, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=64, optimizer=sgd; total time=   9.9s
# [CV] END activation=relu, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=128, optimizer=rmsprop; total time=  11.8s
# [CV] END activation=relu, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=128, optimizer=rmsprop; total time=  12.5s
# [CV] END activation=relu, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=128, optimizer=rmsprop; total time=  11.1s
# [CV] END activation=relu, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=128, optimizer=rmsprop; total time=  10.7s
# [CV] END activation=relu, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=128, optimizer=rmsprop; total time=  10.7s
# [CV] END activation=relu, batch_size=128, dropout=0.5, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=256, optimizer=adam; total time=   9.6s
# [CV] END activation=relu, batch_size=128, dropout=0.5, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=256, optimizer=adam; total time=   9.5s
# [CV] END activation=relu, batch_size=128, dropout=0.5, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=256, optimizer=adam; total time=   8.8s
# [CV] END activation=relu, batch_size=128, dropout=0.5, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=256, optimizer=adam; total time=   7.8s
# [CV] END activation=relu, batch_size=128, dropout=0.5, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=256, optimizer=adam; total time=   8.8s
# [CV] END activation=relu, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=32, optimizer=rmsprop; total time=   8.4s
# [CV] END activation=relu, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=32, optimizer=rmsprop; total time=   6.8s
# [CV] END activation=relu, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=32, optimizer=rmsprop; total time=   8.0s
# [CV] END activation=relu, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=32, optimizer=rmsprop; total time=   6.7s
# [CV] END activation=relu, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=32, optimizer=rmsprop; total time=   9.3s
# [CV] END activation=relu, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=64, optimizer=sgd; total time=   8.2s
# [CV] END activation=relu, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=64, optimizer=sgd; total time=   6.7s
# [CV] END activation=relu, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=64, optimizer=sgd; total time=   8.4s
# [CV] END activation=relu, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=64, optimizer=sgd; total time=   7.6s
# [CV] END activation=relu, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=64, optimizer=sgd; total time=   6.9s
# [CV] END activation=sigmoid, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=64, optimizer=adam; total time=   9.3s
# [CV] END activation=sigmoid, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=64, optimizer=adam; total time=   8.6s
# [CV] END activation=sigmoid, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=64, optimizer=adam; total time=   7.9s
# [CV] END activation=sigmoid, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=64, optimizer=adam; total time=   8.8s
# [CV] END activation=sigmoid, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=64, optimizer=adam; total time=   8.5s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=3, n_neurons=128, optimizer=rmsprop; total time=  14.0s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=3, n_neurons=128, optimizer=rmsprop; total time=  13.7s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=3, n_neurons=128, optimizer=rmsprop; total time=  13.8s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=3, n_neurons=128, optimizer=rmsprop; total time=  14.6s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=3, n_neurons=128, optimizer=rmsprop; total time=  13.8s
# [CV] END activation=tanh, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=128, optimizer=sgd; total time=  12.0s
# [CV] END activation=tanh, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=128, optimizer=sgd; total time=  14.1s
# [CV] END activation=tanh, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=128, optimizer=sgd; total time=  11.8s
# [CV] END activation=tanh, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=128, optimizer=sgd; total time=  11.8s
# [CV] END activation=tanh, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=128, optimizer=sgd; total time=  12.0s
# [CV] END activation=tanh, batch_size=64, dropout=0.5, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=256, optimizer=sgd; total time=   9.7s
# [CV] END activation=tanh, batch_size=64, dropout=0.5, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=256, optimizer=sgd; total time=   9.0s
# [CV] END activation=tanh, batch_size=64, dropout=0.5, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=256, optimizer=sgd; total time=   7.8s
# [CV] END activation=tanh, batch_size=64, dropout=0.5, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=256, optimizer=sgd; total time=   8.9s
# [CV] END activation=tanh, batch_size=64, dropout=0.5, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=256, optimizer=sgd; total time=   8.5s
# [CV] END activation=relu, batch_size=32, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=3, n_neurons=256, optimizer=adam; total time=  15.1s
# [CV] END activation=relu, batch_size=32, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=3, n_neurons=256, optimizer=adam; total time=  13.7s
# [CV] END activation=relu, batch_size=32, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=3, n_neurons=256, optimizer=adam; total time=  13.7s
# [CV] END activation=relu, batch_size=32, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=3, n_neurons=256, optimizer=adam; total time=  13.7s
# [CV] END activation=relu, batch_size=32, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=3, n_neurons=256, optimizer=adam; total time=  17.0s
# [CV] END activation=relu, batch_size=128, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=32, optimizer=rmsprop; total time=   7.1s
# [CV] END activation=relu, batch_size=128, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=32, optimizer=rmsprop; total time=   7.8s
# [CV] END activation=relu, batch_size=128, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=32, optimizer=rmsprop; total time=   6.8s
# [CV] END activation=relu, batch_size=128, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=32, optimizer=rmsprop; total time=   7.8s
# [CV] END activation=relu, batch_size=128, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=2, n_neurons=32, optimizer=rmsprop; total time=   7.5s
# [CV] END activation=relu, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=128, optimizer=sgd; total time=  11.0s
# [CV] END activation=relu, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=128, optimizer=sgd; total time=  11.4s
# [CV] END activation=relu, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=128, optimizer=sgd; total time=  12.0s
# [CV] END activation=relu, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=128, optimizer=sgd; total time=  12.1s
# [CV] END activation=relu, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=128, optimizer=sgd; total time=  11.4s
# [CV] END activation=tanh, batch_size=16, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=1, n_neurons=128, optimizer=sgd; total time=  22.3s
# [CV] END activation=tanh, batch_size=16, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=1, n_neurons=128, optimizer=sgd; total time=  21.3s
# [CV] END activation=tanh, batch_size=16, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=1, n_neurons=128, optimizer=sgd; total time=  20.3s
# [CV] END activation=tanh, batch_size=16, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=1, n_neurons=128, optimizer=sgd; total time=  21.3s
# [CV] END activation=tanh, batch_size=16, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=1, n_neurons=128, optimizer=sgd; total time=  22.0s
# [CV] END activation=tanh, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=1, n_neurons=256, optimizer=rmsprop; total time=   7.9s
# [CV] END activation=tanh, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=1, n_neurons=256, optimizer=rmsprop; total time=   8.9s
# [CV] END activation=tanh, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=1, n_neurons=256, optimizer=rmsprop; total time=   8.6s
# [CV] END activation=tanh, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=1, n_neurons=256, optimizer=rmsprop; total time=   7.9s
# [CV] END activation=tanh, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=1, n_neurons=256, optimizer=rmsprop; total time=   8.7s
# [CV] END activation=sigmoid, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=32, optimizer=sgd; total time=  11.6s
# [CV] END activation=sigmoid, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=32, optimizer=sgd; total time=  12.4s
# [CV] END activation=sigmoid, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=32, optimizer=sgd; total time=  10.9s
# [CV] END activation=sigmoid, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=32, optimizer=sgd; total time=  11.0s
# [CV] END activation=sigmoid, batch_size=64, dropout=0.2, epochs=10, learning_rate=0.001, n_layers=3, n_neurons=32, optimizer=sgd; total time=  10.9s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=1, n_neurons=64, optimizer=sgd; total time=  11.8s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=1, n_neurons=64, optimizer=sgd; total time=  11.5s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=1, n_neurons=64, optimizer=sgd; total time=  11.5s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=1, n_neurons=64, optimizer=sgd; total time=  11.9s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.5, epochs=10, learning_rate=0.01, n_layers=1, n_neurons=64, optimizer=sgd; total time=  11.9s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=64, optimizer=sgd; total time=  11.3s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=64, optimizer=sgd; total time=  11.3s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=64, optimizer=sgd; total time=  11.2s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=64, optimizer=sgd; total time=  12.2s
# [CV] END activation=sigmoid, batch_size=32, dropout=0.0, epochs=10, learning_rate=0.1, n_layers=1, n_neurons=64, optimizer=sgd; total time=  11.3s
# [CV] END activation=sigmoid, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=3, n_neurons=64, optimizer=sgd; total time=   8.2s
# [CV] END activation=sigmoid, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=3, n_neurons=64, optimizer=sgd; total time=   7.9s
# [CV] END activation=sigmoid, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=3, n_neurons=64, optimizer=sgd; total time=   8.6s
# [CV] END activation=sigmoid, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=3, n_neurons=64, optimizer=sgd; total time=   8.4s
# [CV] END activation=sigmoid, batch_size=128, dropout=0.2, epochs=10, learning_rate=0.01, n_layers=3, n_neurons=64, optimizer=sgd; total time=   8.0s
# [CV] END activation=relu, batch_size=16, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=256, optimizer=adam; total time=  22.8s
# [CV] END activation=relu, batch_size=16, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=256, optimizer=adam; total time=  22.7s
# [CV] END activation=relu, batch_size=16, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=256, optimizer=adam; total time=  23.2s
# [CV] END activation=relu, batch_size=16, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=256, optimizer=adam; total time=  22.6s
# [CV] END activation=relu, batch_size=16, dropout=0.2, epochs=10, learning_rate=0.1, n_layers=2, n_neurons=256, optimizer=adam; total time=  22.2s
#
# Search wall time: 19.6 min

# %%
print("Best 5-fold CV accuracy:", round(search.best_score_, 4))
print("\nBest hyperparameters:")
for k, v in sorted(search.best_params_.items()):
    print(f"  {k:14s}: {v}")
# Out:
# Best 5-fold CV accuracy: 0.8543
#
# Best hyperparameters:
#   activation    : tanh
#   batch_size    : 64
#   dropout       : 0.2
#   epochs        : 10
#   learning_rate : 0.001
#   n_layers      : 1
#   n_neurons     : 256
#   optimizer     : rmsprop

# %%
bp = search.best_params_
opt_model = build_model(n_layers=bp['n_layers'], n_neurons=bp['n_neurons'],
                        activation=bp['activation'], dropout=bp['dropout'],
                        optimizer=bp['optimizer'], learning_rate=bp['learning_rate'])
opt_model.summary()

FINAL_EPOCHS = 20
t0 = time.perf_counter()
opt_history = opt_model.fit(x_tr, y_tr, validation_data=(x_val, y_val),
                            epochs=FINAL_EPOCHS, batch_size=bp['batch_size'], verbose=2)
optimized_time = time.perf_counter() - t0
print(f"\nOptimized training time: {optimized_time:.1f} s")
# Out:
# Model: "sequential_102"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_305 (Dense)               │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_181 (Dropout)           │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_306 (Dense)               │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 203,530 (795.04 KB)
#  Trainable params: 203,530 (795.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 782/782 - 13s - 17ms/step - accuracy: 0.7963 - loss: 0.5673 - val_accuracy: 0.8032 - val_loss: 0.5498
# Epoch 2/20
# 782/782 - 5s - 6ms/step - accuracy: 0.8444 - loss: 0.4323 - val_accuracy: 0.8250 - val_loss: 0.4785
# Epoch 3/20
# 782/782 - 7s - 9ms/step - accuracy: 0.8566 - loss: 0.3935 - val_accuracy: 0.8288 - val_loss: 0.4775
# Epoch 4/20
# 782/782 - 2s - 3ms/step - accuracy: 0.8646 - loss: 0.3705 - val_accuracy: 0.8582 - val_loss: 0.3926
# Epoch 5/20
# 782/782 - 2s - 3ms/step - accuracy: 0.8704 - loss: 0.3537 - val_accuracy: 0.8595 - val_loss: 0.3816
# Epoch 6/20
# 782/782 - 3s - 4ms/step - accuracy: 0.8757 - loss: 0.3411 - val_accuracy: 0.8652 - val_loss: 0.3713
# Epoch 7/20
# 782/782 - 2s - 3ms/step - accuracy: 0.8776 - loss: 0.3300 - val_accuracy: 0.8606 - val_loss: 0.3898
# Epoch 8/20
# 782/782 - 2s - 3ms/step - accuracy: 0.8824 - loss: 0.3202 - val_accuracy: 0.8750 - val_loss: 0.3466
# Epoch 9/20
# 782/782 - 2s - 3ms/step - accuracy: 0.8844 - loss: 0.3130 - val_accuracy: 0.8701 - val_loss: 0.3650
# Epoch 10/20
# 782/782 - 2s - 3ms/step - accuracy: 0.8881 - loss: 0.3049 - val_accuracy: 0.8768 - val_loss: 0.3380
# Epoch 11/20
# 782/782 - 3s - 4ms/step - accuracy: 0.8896 - loss: 0.2992 - val_accuracy: 0.8781 - val_loss: 0.3415
# Epoch 12/20
# 782/782 - 2s - 3ms/step - accuracy: 0.8928 - loss: 0.2922 - val_accuracy: 0.8778 - val_loss: 0.3397
# Epoch 13/20
# 782/782 - 2s - 3ms/step - accuracy: 0.8948 - loss: 0.2852 - val_accuracy: 0.8663 - val_loss: 0.3692
# Epoch 14/20
# 782/782 - 3s - 3ms/step - accuracy: 0.8968 - loss: 0.2823 - val_accuracy: 0.8805 - val_loss: 0.3261
# Epoch 15/20
# 782/782 - 2s - 3ms/step - accuracy: 0.8972 - loss: 0.2774 - val_accuracy: 0.8760 - val_loss: 0.3365
# Epoch 16/20
# 782/782 - 3s - 4ms/step - accuracy: 0.9001 - loss: 0.2705 - val_accuracy: 0.8822 - val_loss: 0.3264
# Epoch 17/20
# 782/782 - 2s - 3ms/step - accuracy: 0.9006 - loss: 0.2663 - val_accuracy: 0.8732 - val_loss: 0.3473
# Epoch 18/20
# 782/782 - 2s - 3ms/step - accuracy: 0.9018 - loss: 0.2632 - val_accuracy: 0.8816 - val_loss: 0.3307
# Epoch 19/20
# 782/782 - 2s - 3ms/step - accuracy: 0.9038 - loss: 0.2594 - val_accuracy: 0.8799 - val_loss: 0.3266
# Epoch 20/20
# 782/782 - 2s - 3ms/step - accuracy: 0.9051 - loss: 0.2558 - val_accuracy: 0.8813 - val_loss: 0.3296
#
# Optimized training time: 67.0 s

# %%
optimized_metrics, optimized_pred = evaluate(opt_model, "OPTIMIZED MODEL")
cm_opt = plot_cm(optimized_pred, "Confusion Matrix — Optimized MLP", "07b_confusion_optimized")

labels = ['Accuracy', 'Precision', 'Recall', 'F1-score']
b = [baseline_metrics[k]  for k in ['accuracy','precision','recall','f1']]
o = [optimized_metrics[k] for k in ['accuracy','precision','recall','f1']]

print("\n--- COPY INTO REPORT ---")
print(f"{'Metric':<16}{'Baseline':>12}{'Optimized':>12}")
for lab, bb, oo in zip(labels, b, o):
    print(f"{lab:<16}{bb:>12.4f}{oo:>12.4f}")
print(f"{'Training Time':<16}{baseline_time:>11.1f}s{optimized_time:>11.1f}s")
print("\nBest params:", bp)
print("Best CV accuracy:", round(search.best_score_, 4))
# Out:
# ===== OPTIMIZED MODEL =====
#   Accuracy  : 0.8770
#   Precision : 0.8788
#   Recall    : 0.8770
#   F1        : 0.8756
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  T-shirt/top     0.8444    0.8360    0.8402      1000
#      Trouser     0.9829    0.9770    0.9799      1000
#     Pullover     0.7394    0.8340    0.7838      1000
#        Dress     0.9287    0.8340    0.8788      1000
#         Coat     0.7437    0.8620    0.7985      1000
#       Sandal     0.9714    0.9520    0.9616      1000
#        Shirt     0.7698    0.5920    0.6693      1000
#      Sneaker     0.9537    0.9260    0.9396      1000
#          Bag     0.9282    0.9830    0.9548      1000
#   Ankle boot     0.9259    0.9740    0.9493      1000
#
#     accuracy                         0.8770     10000
#    macro avg     0.8788    0.8770    0.8756     10000
# weighted avg     0.8788    0.8770    0.8756     10000
# --- COPY INTO REPORT ---
# Metric              Baseline   Optimized
# Accuracy              0.8695      0.8770
# Precision             0.8742      0.8788
# Recall                0.8695      0.8770
# F1-score              0.8704      0.8756
# Training Time         115.6s       67.0s
#
# Best params: {'optimizer': 'rmsprop', 'n_neurons': 256, 'n_layers': 1, 'learning_rate': 0.001, 'epochs': 10, 'dropout': 0.2, 'batch_size': 64, 'activation': 'tanh'}
# Best CV accuracy: 0.8543

# %%
h = history.history
specs = [('accuracy',     'Training Accuracy',   'Accuracy', '03_train_accuracy', 'tab:blue'),
         ('val_accuracy', 'Validation Accuracy', 'Accuracy', '04_val_accuracy',   'tab:orange'),
         ('loss',         'Training Loss',        'Loss',     '05_train_loss',     'tab:green'),
         ('val_loss',     'Validation Loss',      'Loss',     '06_val_loss',       'tab:red')]
epochs_range = range(1, len(h['accuracy']) + 1)

for key, title, ylabel, fname, colour in specs:
    plt.figure(figsize=(7, 4))
    plt.plot(epochs_range, h[key], marker='o', ms=3, color=colour)
    plt.xlabel("Epoch"); plt.ylabel(ylabel); plt.title(f"{title} vs Epoch")
    plt.grid(alpha=0.3); plt.tight_layout()
    plt.savefig(f"plots/{fname}.png", dpi=150, bbox_inches='tight')
    plt.show()

# %%
res = pd.DataFrame(search.cv_results_).sort_values('mean_test_score', ascending=False)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].bar(range(len(res)), res['mean_test_score'], yerr=res['std_test_score'],
          capsize=3, color='steelblue', edgecolor='black')
ax[0].set_xlabel("Candidate (ranked best to worst)")
ax[0].set_ylabel("Mean 5-fold CV accuracy")
ax[0].set_title("RandomizedSearchCV — Candidate Performance")
ax[0].grid(axis='y', alpha=0.3)

grp = res.groupby('param_optimizer')['mean_test_score'].mean().sort_values()
ax[1].barh(grp.index.astype(str), grp.values, color='darkorange', edgecolor='black')
ax[1].set_xlabel("Mean CV accuracy"); ax[1].set_title("Mean CV Accuracy by Optimizer")
ax[1].grid(axis='x', alpha=0.3)

plt.tight_layout()
plt.savefig("plots/08_search_results.png", dpi=150, bbox_inches='tight')
plt.show()

# Which hyperparameter mattered most
for p in ['param_learning_rate', 'param_activation', 'param_n_layers', 'param_dropout']:
    print(f"\nMean CV accuracy by {p}:")
    print(res.groupby(p)['mean_test_score'].mean().sort_values(ascending=False))
# Out:
# Mean CV accuracy by param_learning_rate:
# param_learning_rate
# 0.001    0.825389
# 0.010    0.784943
# 0.100    0.284543
# Name: mean_test_score, dtype: float64
#
# Mean CV accuracy by param_activation:
# param_activation
# sigmoid    0.795550
# tanh       0.588983
# relu       0.464800
# Name: mean_test_score, dtype: float64
#
# Mean CV accuracy by param_n_layers:
# param_n_layers
# 3    0.714762
# 1    0.684867
# 2    0.440222
# Name: mean_test_score, dtype: float64
#
# Mean CV accuracy by param_dropout:
# param_dropout
# 0.5    0.735989
# 0.2    0.640109
# 0.0    0.327200
# Name: mean_test_score, dtype: float64

# %%
labels = ['Accuracy', 'Precision', 'Recall', 'F1-score']
b = [baseline_metrics[k]  for k in ['accuracy','precision','recall','f1']]
o = [optimized_metrics[k] for k in ['accuracy','precision','recall','f1']]

x = np.arange(4); w = 0.35
plt.figure(figsize=(9, 5))
plt.bar(x - w/2, b, w, label='Baseline',  color='red',  edgecolor='black')
plt.bar(x + w/2, o, w, label='Optimized', color='yellow', edgecolor='black')
for i in range(4):
    plt.text(i - w/2, b[i] + 0.005, f"{b[i]:.3f}", ha='center', fontsize=8)
    plt.text(i + w/2, o[i] + 0.005, f"{o[i]:.3f}", ha='center', fontsize=8)
plt.xticks(x, labels); plt.ylim(0, 1.05); plt.ylabel("Score")
plt.title("Baseline vs Optimized MLP — Performance Comparison")
plt.legend(); plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig("plots/09_model_comparison.png", dpi=150, bbox_inches='tight')
plt.show()

# %%
import os; os.makedirs("plots", exist_ok=True)
import numpy as np
import matplotlib.pyplot as plt

X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,1,1,0])
Xb = np.c_[np.ones(len(X)), X]

w = np.zeros(3)
lr = 0.1
epochs = 15

def plot_boundary(w, update_no):
    plt.figure(figsize=(4.5, 4.5))
    for xi, target in zip(X, y):
        plt.scatter(*xi, c='tab:pink' if target == 1 else 'tab:purple',
                    s=120, edgecolors='black', zorder=3)
    if abs(w[2]) > 1e-6:
        xs = np.linspace(-0.5, 1.5, 100)
        plt.plot(xs, -(w[0] + w[1]*xs)/w[2], 'k--')
    plt.xlim(-0.5, 1.5); plt.ylim(-0.5, 1.5)
    plt.xlabel("x1"); plt.ylabel("x2")
    plt.title(f"XOR — Boundary after update {update_no}")
    plt.grid(alpha=0.3); plt.tight_layout()
    plt.savefig(f"plots/xor_update_{update_no:02d}.png", dpi=150, bbox_inches='tight')
    plt.show()

print("Initial weights:", w)
update_no = 0
for epoch in range(epochs):
    errors = 0
    for xi, target in zip(Xb, y):
        pred = 1 if np.dot(w, xi) >= 0 else 0
        delta = lr * (target - pred)
        if delta != 0:
            w = w + delta * xi
            errors += 1
            update_no += 1
            print(f"epoch {epoch+1}: input {xi[1:]}, target {target}, pred {pred} "
                  f"-> weights {np.round(w, 3)}")
            plot_boundary(w, update_no)
    if errors == 0:
        print(f"Converged after epoch {epoch+1}")
        break
else:
    print(f"\nNo convergence after {epochs} epochs — "
          f"weights kept changing every epoch ({update_no} total updates).")
# Out:
# Initial weights: [0. 0. 0.]
# epoch 1: input [0. 0.], target 0, pred 1 -> weights [-0.1  0.   0. ]
# epoch 1: input [0. 1.], target 1, pred 0 -> weights [0.  0.  0.1]
# epoch 1: input [1. 1.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 2: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 2: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 2: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 3: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 3: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 3: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 3: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 4: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 4: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 4: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 4: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 5: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 5: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 5: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 5: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 6: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 6: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 6: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 6: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 7: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 7: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 7: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 7: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 8: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 8: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 8: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 8: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 9: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 9: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 9: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 9: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 10: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 10: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 10: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 10: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 11: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 11: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 11: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 11: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 12: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 12: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 12: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 12: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 13: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 13: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 13: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 13: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 14: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 14: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 14: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 14: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# epoch 15: input [0. 0.], target 0, pred 1 -> weights [-0.1 -0.1  0. ]
# epoch 15: input [0. 1.], target 1, pred 0 -> weights [ 0.  -0.1  0.1]
# epoch 15: input [1. 0.], target 1, pred 0 -> weights [0.1 0.  0.1]
# epoch 15: input [1. 1.], target 0, pred 1 -> weights [ 0.  -0.1  0. ]
# No convergence after 15 epochs — weights kept changing every epoch (58 total updates).
